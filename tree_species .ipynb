# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Datasets/
# Out:
# /content/drive/MyDrive/Datasets

# %%
# !unzip Tree_Species.zip -d extracted_data/
# Out:
# Archive:  Tree_Species.zip
# replace extracted_data/Tree_Species_Dataset/.git/HEAD? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: extracted_data/Tree_Species_Dataset/.git/HEAD
#   inflating: extracted_data/Tree_Species_Dataset/.git/config
#   inflating: extracted_data/Tree_Species_Dataset/.git/description
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/applypatch-msg.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/commit-msg.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/fsmonitor-watchman.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/post-update.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/pre-applypatch.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/pre-commit.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/pre-merge-commit.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/pre-push.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/pre-rebase.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/pre-receive.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/prepare-commit-msg.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/push-to-checkout.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/hooks/update.sample
#   inflating: extracted_data/Tree_Species_Dataset/.git/info/exclude
#   inflating: extracted_data/Tree_Species_Dataset/amla/1.jpg
#   inflating: extracted_data/Tree_Species_Dataset/amla/2.jpg
#   inflating: extracted_data/Tree_Species_Dataset/amla/3.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/4.jpg
#   inflating: extracted_data/Tree_Species_Dataset/amla/5.jpg
#   inflating: extracted_data/Tree_Species_Dataset/amla/6.jpg
#   inflating: extracted_data/Tree_Species_Dataset/amla/7.jpg
#   inflating: extracted_data/Tree_Species_Dataset/amla/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (34).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (35).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (36).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (37).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (38).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (39).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/amla/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/1.jpg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/2.jpg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/3.jpg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/4.jpg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (34).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (35).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (36).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (37).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (38).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (39).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (40).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/asopalav/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/1.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/2.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/3.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/4.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/5.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/6.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/7.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/8.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/9.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/babool (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/babul/large.jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/unnamed (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/unnamed (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/babul/unnamed.jpg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bamboo/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/banyan/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/download1.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (34).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (35).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (36).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (37).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/bili/t77-1448877.jpg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (34).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/cactus/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (10).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (3).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (4).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (5).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (6).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (7).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (8).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download (9).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/champa/download.jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (10).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (11).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (12).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (13).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (14).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (15).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (16).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (17).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (18).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (19).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (20).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (21).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (22).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (23).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (24).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (25).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (26).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (27).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (28).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (29).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (3).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (30).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (31).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (32).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (33).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (34).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (4).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (5).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (6).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (7).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (8).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images (9).jpg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/champa/images.jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/640px-Singapore_coconut.jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download (3).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download (4).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download (5).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download (6).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download (7).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/download.jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (10).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (11).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (12).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (13).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (14).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (15).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (16).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (17).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (18).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (19).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (20).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (21).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (22).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (23).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (24).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (25).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (26).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (27).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (28).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (29).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (3).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (30).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (31).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (32).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (33).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (34).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (35).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (36).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (37).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (38).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (39).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (4).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (40).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (5).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (6).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (7).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (8).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images (9).jpg
#   inflating: extracted_data/Tree_Species_Dataset/coconut/images.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image1.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image10.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image11.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image12.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image13.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image14.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image15.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image16.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image17.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image18.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image19.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image2.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image20.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image21.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image22.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image23.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image24.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image25.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image26.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image27.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image28.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image29.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image3.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image30.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image31.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image32.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image33.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image34.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image35.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image36.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image37.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image38.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image39.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image4.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image40.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image41.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image42.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image43.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image44.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image45.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image5.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image6.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image7.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image8.jpg
#   inflating: extracted_data/Tree_Species_Dataset/garmalo/image9.jpg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/KPPCONT_036133_fullsize.jpg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/download1.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (34).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (35).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (36).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (37).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (38).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (39).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gulmohor/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (3).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (4).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (8).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/download.jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/image.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (10).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (11).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (12).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (13).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (14).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (15).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (16).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (17).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (18).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (3).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (4).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (5).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (6).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (7).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (8).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images (9).jpg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/gunda/images.jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/download (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/download.jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (1).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (10).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (11).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (12).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (13).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (14).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (15).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (16).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (17).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (18).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (19).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (2).jpg
#   inflating: extracted_data/Tree_Species_Dataset/jamun/images (20).jpg
# ...
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (40).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (41).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (42).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (43).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/simlo/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/download1.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (34).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (35).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (36).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (37).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (38).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (39).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (40).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (41).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sitafal/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sonmahor/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (35).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/sugarcane/images.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/download.jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (1).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (10).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (11).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (12).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (13).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (14).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (15).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (16).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (17).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (18).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (19).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (2).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (20).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (21).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (22).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (23).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (24).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (25).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (26).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (27).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (28).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (29).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (3).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (30).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (31).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (32).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (33).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (34).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (4).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (5).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (6).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (7).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (8).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images (9).jpeg
#   inflating: extracted_data/Tree_Species_Dataset/vad/images.jpeg

# %%
data_dir = '/content/drive/MyDrive/Datasets/extracted_data/Tree_Species_Dataset'

# %%
print(data_dir)
# Out:
# /content/drive/MyDrive/Datasets/extracted_data/Tree_Species_Dataset

# %%
import os
print("class folder:")
print(os.listdir(data_dir))
# Out:
# class folder:
# ['.git', 'amla', 'asopalav', 'babul', 'bamboo', 'banyan', 'bili', 'cactus', 'champa', 'coconut', 'garmalo', 'gulmohor', 'gunda', 'jamun', 'kanchan', 'kesudo', 'khajur', 'mango', 'motichanoti', 'neem', 'nilgiri', 'other', 'pilikaren', 'pipal', 'saptaparni', 'shirish', 'simlo', 'sitafal', 'sonmahor', 'sugarcane', 'vad']

# %%
import os
from PIL import Image

corrupt_images = []

# Code to identify corrupted images (originally in cell 0U1zFP43gU2u)
for class_name in os.listdir(data_dir):
    class_folder = os.path.join(data_dir, class_name)
    if os.path.isdir(class_folder) and class_name != '.git':
        for img_file in os.listdir(class_folder):
            img_path = os.path.join(class_folder, img_file)
            try:
                img = Image.open(img_path)
                img.verify()
            except Exception as e:
                corrupt_images.append(img_path)

print("Corrupted images identified:", len(corrupt_images))


# Code to remove corrupted images (originally in this cell)
for img_path in corrupt_images:
    try:
        os.remove(img_path)
        print(f"Removed corrupted image: {img_path}")
    except OSError as e:
        print(f"Error removing image {img_path}: {e}")

print(f"Finished removing {len(corrupt_images)} corrupted images.")
# Out:
# Corrupted images identified: 0
# Finished removing 0 corrupted images.

# %%
from genericpath import isdir
import glob
image_paths=[]
labels=[]
for class_name in os.listdir(data_dir):
  class_folder=os.path.join(data_dir,class_name)
  if os.path.isdir(class_folder):
    for img_file in os.listdir(class_folder):
      image_paths.append(os.path.join(class_folder,img_file))
      labels.append(class_name)
print(f"Total images: {len(image_paths)}")
# Out:
# Total images: 1605

# %%
import pandas as pd

class_counts = {cls: len(os.listdir(os.path.join(data_dir, cls))) for cls in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, cls)) and cls != '.git'}
class_counts_df = pd.DataFrame.from_dict(class_counts, orient='index', columns=['Image Count'])
print(class_counts_df.sort_values('Image Count', ascending=False).head())
print("shape: ",class_counts_df.shape)
# Out:
#         Image Count
# other           150
# amla             50
# babul            50
# bamboo           50
# banyan           50
# shape:  (30, 1)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

def show_sample_images(data_dir, class_list, n=5):
    plt.figure(figsize=(15, 10))
    image_classes = [c for c in class_list if c != '.git'] # Exclude .git folder
    for i, class_name in enumerate(image_classes[:n]):
        class_folder = os.path.join(data_dir, class_name)
        if os.path.isdir(class_folder):
            img_files = os.listdir(class_folder)
            if img_files: # Check if the folder is not empty
                img_path = os.path.join(class_folder, img_files[0])
                img = Image.open(img_path)
                plt.subplot(1, n, i+1)
                plt.imshow(img)
                plt.title(class_name)
                plt.axis('off')
    plt.show()

show_sample_images(data_dir, class_counts)

# %%
image_shapes = []

for class_name in os.listdir(data_dir):
    class_folder = os.path.join(data_dir, class_name)
    if os.path.isdir(class_folder) and class_name != '.git':
        for img_file in os.listdir(class_folder):
            img_path = os.path.join(class_folder, img_file)
            try:
                img = Image.open(img_path)
                image_shapes.append(img.size)
            except UnidentifiedImageError:
                print(f"Could not identify image file: {img_path}")


# DataFrame and Summary
import pandas as pd

shapes_df = pd.DataFrame(image_shapes, columns=["Width", "Height"])
shapes_df.head()
# Out:
#    Width  Height
# 0    194     259
# 1    225     225
# 2    198     254
# 3    177     285
# 4    224     225

# %%
print(shapes_df.describe())
# Out:
#              Width       Height
# count  1600.000000  1600.000000
# mean    312.623125   269.821875
# std     296.220501   278.014229
# min     141.000000   128.000000
# 25%     225.000000   183.000000
# 50%     259.000000   200.000000
# 75%     275.000000   259.000000
# max    4000.000000  4032.000000

# %%
import hashlib
from collections import defaultdict
import os

hashes = defaultdict(list)

for class_name in class_counts:
    class_folder = os.path.join(data_dir, class_name)
    if os.path.isdir(class_folder) and class_name != '.git':
        for img_file in os.listdir(class_folder):
            img_path = os.path.join(class_folder, img_file)
            if os.path.isfile(img_path): # Check if it's a file before opening
                with open(img_path, 'rb') as f:
                    file_hash = hashlib.md5(f.read()).hexdigest()
                    hashes[file_hash].append(img_path)

# Filter duplicates
duplicates = {h: files for h, files in hashes.items() if len(files) > 1}
print("Duplicate image sets found:", len(duplicates))
# Out:
# Duplicate image sets found: 82

# %%
corrupt_images = []

for class_count in class_counts:
    for img_file in os.listdir(os.path.join(data_dir, class_count)):
        img_path = os.path.join(data_dir, class_count, img_file)
        try:
            img = Image.open(img_path)
            img.verify()
        except Exception as e:
            corrupt_images.append(img_path)

print("Corrupted images:", len(corrupt_images))
# Out:
# Corrupted images: 0

# %%
import matplotlib.pyplot as plt
from PIL import Image

def show_duplicate_sets(duplicates, sets_to_display=3):
    shown = 0
    for hash_val, dup_paths in duplicates.items():
        if shown >= sets_to_display:
            break
        print(f"Duplicate set {shown + 1}:")
        plt.figure(figsize=(15, 4))
        for i, img_path in enumerate(dup_paths):
            try:
                img = Image.open(img_path)
                plt.subplot(1, len(dup_paths), i+1)
                plt.imshow(img)
                plt.title(os.path.basename(img_path))
                plt.axis('off')
            except:
                continue
        plt.show()
        shown += 1

show_duplicate_sets(duplicates, sets_to_display=3)
# Out:
# Duplicate set 1:
# Duplicate set 2:
# Duplicate set 3:

# %%
import os

removed_count = 0

for dup_list in duplicates.values():
    # Keep the first, delete rest
    for img_path in dup_list[1:]:
        try:
            os.remove(img_path)
            removed_count += 1
        except Exception as e:
            print(f"Error deleting {img_path}: {e}")

print(f"✅ Removed {removed_count} duplicate images.")
# Out:
# ✅ Removed 86 duplicate images.

# %%
hashes = defaultdict(list)

for class_name in class_count:
    class_folder = os.path.join(data_dir, class_name)
    if os.path.isdir(class_folder) and class_name != '.git':
        for img_file in os.listdir(class_folder):
            img_path = os.path.join(class_folder, img_file)
            if os.path.isfile(img_path): # Check if it's a file before opening
                with open(img_path, 'rb') as f:
                    file_hash = hashlib.md5(f.read()).hexdigest()
                    hashes[file_hash].append(img_path)

# Filter duplicates
duplicates = {h: files for h, files in hashes.items() if len(files) > 1}
print("Duplicate Remaining:", len(duplicates))
# Out:
# Duplicate Remaining: 0

# %%
from PIL import Image
import pandas as pd
import os

# Gather image info
image_info = []

for class_name in class_counts.keys(): # Iterate through the keys of the class_counts dictionary
    class_path = os.path.join(data_dir, class_name)
    if os.path.isdir(class_path) and class_name != '.git':
        for img_file in os.listdir(class_path):
            img_path = os.path.join(class_path, img_file)
            try:
                with Image.open(img_path) as img:
                    width, height = img.size
                    image_info.append({
                        'path': img_path,
                        'width': width,
                        'height': height,
                        'class': class_name
                    })
            except Exception as e:
                print(f"Could not process image file {img_path}: {e}")


df_sizes = pd.DataFrame(image_info)

# Define thresholds
small_imgs = df_sizes[(df_sizes['width'] < 150) | (df_sizes['height'] < 150)]
large_imgs = df_sizes[(df_sizes['width'] > 1000) | (df_sizes['height'] > 2000)]

print(f"🔻 Very small images: {len(small_imgs)}")
print(f"🔺 Very large images: {len(large_imgs)}")
# Out:
# 🔻 Very small images: 20
# 🔺 Very large images: 40

# %%
def show_images(df_subset, title, n=5):
    plt.figure(figsize=(15, 3))
    for i, (_, row) in enumerate(df_subset.head(n).iterrows()):
        img = Image.open(row['path'])
        plt.subplot(1, n, i+1)
        plt.imshow(img)
        plt.title(f"{row['width']}x{row['height']}")
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

show_images(small_imgs, "Very Small Images")
show_images(large_imgs, "Very Large Images")

# %%
import os

# Combine both sets
outliers = pd.concat([small_imgs, large_imgs])

# Remove them
removed_count = 0
for path in outliers['path']:
    try:
        os.remove(path)
        removed_count += 1
    except Exception as e:
        print(f"Failed to remove {path}: {e}")

print(f"🗑️ Removed {removed_count} outlier images (small + large).")
# Out:
# 🗑️ Removed 60 outlier images (small + large).

# %%
# Recalculate sizes
image_info = []

for class_name in class_counts.keys(): # Iterate through the keys of the class_counts dictionary
    class_path = os.path.join(data_dir, class_name)
    if os.path.isdir(class_path) and class_name != '.git':
        for img_file in os.listdir(class_path):
            img_path = os.path.join(class_path, img_file)
            try:
                with Image.open(img_path) as img:
                    width, height = img.size
                    image_info.append({
                        'path': img_path,
                        'width': width,
                        'height': height,
                        'class': class_name
                    })
            except Exception as e:
                # It's good practice to print the error for debugging
                print(f"Could not process image file {img_path}: {e}")


df_sizes = pd.DataFrame(image_info)
print(df_sizes[['width', 'height']].describe())
# Out:
#              width       height
# count  1454.000000  1454.000000
# mean    275.872765   239.044704
# std     117.507849   117.197342
# min     150.000000   150.000000
# 25%     225.000000   183.000000
# 50%     259.000000   198.000000
# 75%     275.000000   256.000000
# max    1000.000000  1247.000000

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define parameters
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Augmentation and rescaling
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)

train_gen = datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 1177 images belonging to 31 classes.
# Found 277 images belonging to 31 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

base_model = EfficientNetB0(include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), weights='imagenet')
base_model.trainable = False  # Freeze base model

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(train_gen.num_classes, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 31)             │         3,999 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,217,538 (16.09 MB)
#  Trainable params: 167,967 (656.12 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
EPOCHS = 10

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.0584 - loss: 3.4578 - val_accuracy: 0.0903 - val_loss: 3.3999
# Epoch 2/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 23s 637ms/step - accuracy: 0.0544 - loss: 3.4360 - val_accuracy: 0.0903 - val_loss: 3.3859
# Epoch 3/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 24s 641ms/step - accuracy: 0.0916 - loss: 3.4135 - val_accuracy: 0.0903 - val_loss: 3.3912
# Epoch 4/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 22s 607ms/step - accuracy: 0.0809 - loss: 3.4059 - val_accuracy: 0.0903 - val_loss: 3.3830
# Epoch 5/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 24s 640ms/step - accuracy: 0.0841 - loss: 3.4098 - val_accuracy: 0.0903 - val_loss: 3.3874
# Epoch 6/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 24s 641ms/step - accuracy: 0.0819 - loss: 3.4043 - val_accuracy: 0.0903 - val_loss: 3.3858
# Epoch 7/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 41s 630ms/step - accuracy: 0.0731 - loss: 3.3954 - val_accuracy: 0.0903 - val_loss: 3.3740
# Epoch 8/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 23s 627ms/step - accuracy: 0.1006 - loss: 3.3649 - val_accuracy: 0.0903 - val_loss: 3.3756
# Epoch 9/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 23s 612ms/step - accuracy: 0.0807 - loss: 3.3920 - val_accuracy: 0.0903 - val_loss: 3.3720
# Epoch 10/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 24s 651ms/step - accuracy: 0.0822 - loss: 3.3933 - val_accuracy: 0.0903 - val_loss: 3.3712

# %%
# Plot accuracy/loss curves
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Accuracy Over Epochs")
plt.show()

# Save model
model.save("tree_species_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define image properties
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Data generators
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Number of output classes
num_classes = train_generator.num_classes

# Build a basic CNN model
model_cnn = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model_cnn.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the model
EPOCHS = 10
history_cnn = model_cnn.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)

# Save the model
model_cnn.save('basic_cnn_tree_species.h5')
print("✅ Basic CNN model saved as 'basic_cnn_tree_species.h5'")
# Out:
# Found 1177 images belonging to 31 classes.
# Found 277 images belonging to 31 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 45s 967ms/step - accuracy: 0.0615 - loss: 3.7892 - val_accuracy: 0.0903 - val_loss: 3.3034
# Epoch 2/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 760ms/step - accuracy: 0.0868 - loss: 3.2821 - val_accuracy: 0.1011 - val_loss: 3.2194
# Epoch 3/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 27s 746ms/step - accuracy: 0.1008 - loss: 3.1779 - val_accuracy: 0.1552 - val_loss: 2.9916
# Epoch 4/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 753ms/step - accuracy: 0.1427 - loss: 3.0218 - val_accuracy: 0.1986 - val_loss: 2.8624
# Epoch 5/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 752ms/step - accuracy: 0.1953 - loss: 2.8680 - val_accuracy: 0.2022 - val_loss: 2.7618
# Epoch 6/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 758ms/step - accuracy: 0.2166 - loss: 2.7956 - val_accuracy: 0.2671 - val_loss: 2.6180
# Epoch 7/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 761ms/step - accuracy: 0.2147 - loss: 2.7298 - val_accuracy: 0.3032 - val_loss: 2.5416
# Epoch 8/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 753ms/step - accuracy: 0.2553 - loss: 2.5991 - val_accuracy: 0.3032 - val_loss: 2.4580
# Epoch 9/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 760ms/step - accuracy: 0.2875 - loss: 2.5535 - val_accuracy: 0.2924 - val_loss: 2.4381
# Epoch 10/10
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 760ms/step - accuracy: 0.2862 - loss: 2.4641 - val_accuracy: 0.3321 - val_loss: 2.4163
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Basic CNN model saved as 'basic_cnn_tree_species.h5'

# %%
import matplotlib.pyplot as plt

plt.plot(history_cnn.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn.history['val_accuracy'], label='Validation Accuracy')
plt.title("Basic CNN Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(31, activation='softmax')  # For 31 classes
])

model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_generator, validation_data=val_generator, epochs=25)

model.save("improved_cnn_model.h5")
# Out:
# Epoch 1/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 41s 892ms/step - accuracy: 0.0673 - loss: 5.5033 - val_accuracy: 0.0505 - val_loss: 7.8904
# Epoch 2/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 754ms/step - accuracy: 0.1019 - loss: 3.2710 - val_accuracy: 0.0325 - val_loss: 15.3944
# Epoch 3/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 27s 744ms/step - accuracy: 0.1426 - loss: 3.1672 - val_accuracy: 0.0325 - val_loss: 21.0014
# Epoch 4/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 752ms/step - accuracy: 0.1469 - loss: 3.1217 - val_accuracy: 0.0325 - val_loss: 22.8061
# Epoch 5/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 759ms/step - accuracy: 0.1738 - loss: 3.0573 - val_accuracy: 0.0325 - val_loss: 22.8001
# Epoch 6/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 761ms/step - accuracy: 0.1788 - loss: 2.9877 - val_accuracy: 0.0325 - val_loss: 18.9414
# Epoch 7/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 33s 887ms/step - accuracy: 0.1566 - loss: 2.9676 - val_accuracy: 0.0325 - val_loss: 14.8296
# Epoch 8/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 760ms/step - accuracy: 0.1519 - loss: 3.0486 - val_accuracy: 0.0289 - val_loss: 13.4513
# Epoch 9/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 759ms/step - accuracy: 0.1852 - loss: 2.9463 - val_accuracy: 0.0433 - val_loss: 11.2053
# Epoch 10/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 748ms/step - accuracy: 0.2192 - loss: 2.8354 - val_accuracy: 0.0505 - val_loss: 9.7259
# Epoch 11/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 755ms/step - accuracy: 0.2060 - loss: 2.8675 - val_accuracy: 0.1047 - val_loss: 6.8145
# Epoch 12/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 754ms/step - accuracy: 0.2164 - loss: 2.8724 - val_accuracy: 0.1625 - val_loss: 5.1621
# Epoch 13/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 759ms/step - accuracy: 0.2467 - loss: 2.8225 - val_accuracy: 0.1372 - val_loss: 4.4483
# Epoch 14/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 763ms/step - accuracy: 0.1987 - loss: 2.8943 - val_accuracy: 0.1949 - val_loss: 3.9200
# Epoch 15/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 754ms/step - accuracy: 0.2229 - loss: 2.8117 - val_accuracy: 0.2094 - val_loss: 3.8839
# Epoch 16/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 762ms/step - accuracy: 0.1985 - loss: 2.8724 - val_accuracy: 0.2166 - val_loss: 3.3961
# Epoch 17/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 758ms/step - accuracy: 0.2414 - loss: 2.7202 - val_accuracy: 0.2310 - val_loss: 3.1327
# Epoch 18/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 763ms/step - accuracy: 0.2621 - loss: 2.6977 - val_accuracy: 0.2094 - val_loss: 3.0513
# Epoch 19/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 768ms/step - accuracy: 0.2439 - loss: 2.6887 - val_accuracy: 0.2347 - val_loss: 2.9091
# Epoch 20/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 758ms/step - accuracy: 0.2256 - loss: 2.7419 - val_accuracy: 0.2599 - val_loss: 2.9797
# Epoch 21/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 760ms/step - accuracy: 0.2593 - loss: 2.6397 - val_accuracy: 0.2852 - val_loss: 3.0385
# Epoch 22/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 748ms/step - accuracy: 0.2791 - loss: 2.5844 - val_accuracy: 0.2455 - val_loss: 2.8761
# Epoch 23/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 41s 750ms/step - accuracy: 0.2881 - loss: 2.5937 - val_accuracy: 0.2455 - val_loss: 2.9689
# Epoch 24/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 757ms/step - accuracy: 0.2897 - loss: 2.5916 - val_accuracy: 0.2816 - val_loss: 2.8616
# Epoch 25/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 28s 759ms/step - accuracy: 0.2982 - loss: 2.5110 - val_accuracy: 0.2852 - val_loss: 2.9510
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print(list(train_generator.class_indices.keys()))
# Out:
# ['.git', 'amla', 'asopalav', 'babul', 'bamboo', 'banyan', 'bili', 'cactus', 'champa', 'coconut', 'garmalo', 'gulmohor', 'gunda', 'jamun', 'kanchan', 'kesudo', 'khajur', 'mango', 'motichanoti', 'neem', 'nilgiri', 'other', 'pilikaren', 'pipal', 'saptaparni', 'shirish', 'simlo', 'sitafal', 'sonmahor', 'sugarcane', 'vad']

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np

model = load_model('improved_cnn_model.h5')
class_names = ['.git', 'amla', 'asopalav', 'babul', 'bamboo', 'banyan', 'bili', 'cactus',
               'champa', 'coconut', 'garmalo', 'gulmohor', 'gunda', 'jamun', 'kanchan', 'kesudo', 'khajur',
               'mango', 'motichanoti', 'neem', 'nilgiri', 'other', 'pilikaren', 'pipal', 'saptaparni', 'shirish', 'simlo',
               'sitafal', 'sonmahor', 'sugarcane', 'vad']  # Full list needed

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(224, 224))
    img_array = img_to_array(img)
    img_array = img_array / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

def predict_tree_species(image_path):
    processed_image = preprocess_image(image_path)
    predictions = model.predict(processed_image)
    predicted_class_idx = np.argmax(predictions[0])
    predicted_class = class_names[predicted_class_idx]
    confidence = predictions[0][predicted_class_idx] * 100
    return predicted_class, confidence

image_path = '/content/image14.jpg'
predicted_class, confidence = predict_tree_species(image_path)
print(f'Predicted Tree Species: {predicted_class}')
print(f'Confidence: {confidence:.2f}%')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted Tree Species: motichanoti
# Confidence: 3.32%
